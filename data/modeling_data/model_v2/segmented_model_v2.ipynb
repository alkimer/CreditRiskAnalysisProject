# %% [markdown]
# # ---  2-phase Model ---

# %% [markdown]
# ## Start

# %%
from segmented_model_v2 import *
import pandas as pd


X_train = pd.read_csv('../../processed/v2/balanced/X_train_processed_bal.csv')
y_train = pd.read_csv('../../processed/v2/balanced/y_train_bal.csv')

X_val = pd.read_csv('../../processed/v2/X_val_processed.csv')
y_val = pd.read_csv('../../processed/v2/y_val.csv')

# %% [markdown]
# # Phase 1: Segmentation

# %% [markdown]
# ## K-means Segmentation

# %% [markdown]
# ### 2-cluster K-means

# %%
km_clusters = 2
df_kmeans_segmented2 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented2, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 2):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.511795
# 0    0.488205
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.50675
# 1    0.49325
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 3-cluster K-means

# %%
km_clusters = 3
df_kmeans_segmented3 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented3, km_clusters)
# Out:
# --- K-Means Segmentation ---
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### 4-cluster K-means

# %%
km_clusters = 4
df_kmeans_segmented4 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented4, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 4):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.503378
# 0    0.496622
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 1    0.527988
# 0    0.472012
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 0    0.579723
# 1    0.420277
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 1    0.516836
# 0    0.483164
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 5-cluster K-means

# %%
km_clusters = 5
df_kmeans_segmented5 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented5, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 5):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.526798
# 0    0.473202
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 1    0.513798
# 0    0.486202
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.516292
# 0    0.483708
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.580141
# 1    0.419859
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    0.8
# 0    0.2
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 6-cluster K-means

# %%
km_clusters = 6
df_kmeans_segmented6 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented6, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 6):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.517399
# 0    0.482601
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.579998
# 1    0.420002
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.503486
# 0    0.496514
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 1    0.513838
# 0    0.486162
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    0.527318
# 0    0.472682
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 1    0.8
# 0    0.2
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ## Decision Trees Segmentation

# %% [markdown]
# ### Decision trees, max_leafs = 2

# %%
dt_leafs = 2
df_dt_segmented2 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented2, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
#
# Decision Tree segments distribution (Max leaf nodes aimed: 2):
# dt_segment
# 2    37781
# 1    21267
# Name: count, dtype: int64
#
# Target variable distribution within Decision Tree segments:
# Segment 1:
# target
# 1    0.594489
# 0    0.405511
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 0    0.553188
# 1    0.446812
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### Decision trees, max_leafs = 3

# %%
dt_leafs = 3
df_dt_segmented3 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented3, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
#
# Decision Tree segments distribution (Max leaf nodes aimed: 3):
# dt_segment
# 2    37781
# 3    16850
# 4     4417
# Name: count, dtype: int64
#
# Target variable distribution within Decision Tree segments:
# Segment 2:
# target
# 0    0.553188
# 1    0.446812
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.51181
# 1    0.48819
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    1.0
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### Decision trees, max_leafs = 4

# %%
dt_leafs = 4
df_dt_segmented4 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented4, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
#
# Decision Tree segments distribution (Max leaf nodes aimed: 4):
# dt_segment
# 6    29237
# 3    16850
# 5     8544
# 4     4417
# Name: count, dtype: int64
#
# Target variable distribution within Decision Tree segments:
# Segment 3:
# target
# 0    0.51181
# 1    0.48819
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    1.0
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 1    0.57713
# 0    0.42287
# Name: proportion, dtype: float64
# --------------------
# Segment 6:
# target
# 0    0.591271
# 1    0.408729
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### Decision trees, max_leafs = 5

# %%
dt_leafs = 5
df_dt_segmented5 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented5, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
#
# Decision Tree segments distribution (Max leaf nodes aimed: 5):
# dt_segment
# 6    29237
# 3    16850
# 7     6741
# 4     4417
# 8     1803
# Name: count, dtype: int64
#
# Target variable distribution within Decision Tree segments:
# Segment 3:
# target
# 0    0.51181
# 1    0.48819
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    1.0
# Name: proportion, dtype: float64
# --------------------
# Segment 6:
# target
# 0    0.591271
# 1    0.408729
# Name: proportion, dtype: float64
# --------------------
# Segment 7:
# target
# 0    0.535974
# 1    0.464026
# Name: proportion, dtype: float64
# --------------------
# Segment 8:
# target
# 1    1.0
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### Decision trees, max_leafs = 6

# %%
dt_leafs = 6
df_dt_segmented6 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented6, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
#
# Decision Tree segments distribution (Max leaf nodes aimed: 6):
# dt_segment
# 9     19710
# 3     16850
# 10     9527
# 7      6741
# 4      4417
# 8      1803
# Name: count, dtype: int64
#
# Target variable distribution within Decision Tree segments:
# Segment 3:
# target
# 0    0.51181
# 1    0.48819
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    1.0
# Name: proportion, dtype: float64
# --------------------
# Segment 7:
# target
# 0    0.535974
# 1    0.464026
# Name: proportion, dtype: float64
# --------------------
# Segment 8:
# target
# 1    1.0
# Name: proportion, dtype: float64
# --------------------
# Segment 9:
# target
# 0    0.528615
# 1    0.471385
# Name: proportion, dtype: float64
# --------------------
# Segment 10:
# target
# 0    0.720898
# 1    0.279102
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# # ---------------

# %% [markdown]
# # Phase 2: Logistic Regression

# %%
segmentations = [df_kmeans_segmented2,
                 df_kmeans_segmented3,
                 df_kmeans_segmented4,
                 df_kmeans_segmented5,
                 df_kmeans_segmented6,
                 df_dt_segmented2]#,
                 #df_dt_segmented3,
                 #df_dt_segmented4,
                 #df_dt_segmented5,
                 #df_dt_segmented6]

segmentation_names=['2-cluster K-means',
                    '3-cluster K-means',
                    '4-cluster K-means',
                    '5-cluster K-means',
                    '6-cluster K-means',
                    '2-cluster Decision Trees']#,                    
                    #'3-cluster Decision Trees',
                    #'4-cluster Decision Trees',
                    #'5-cluster Decision Trees',
                    #'6-cluster Decision Trees']

# %%
all_metrics = []
for i in range(len(segmentations)):
    print("-"*50,"\n-----", segmentation_names[i], "-----\n")
    case_metrics = second_phase(segmentations[i], X_val, y_val)
    all_metrics.append(case_metrics)
# Out:
# --------------------------------------------------
# ----- 2-cluster K-means -----
#
# // Segment # 1 //
# Confusion Matrix:
# [[2337 5098]
#  [ 558 2007]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.31      0.45      7435
#            1       0.28      0.78      0.42      2565
#
#     accuracy                           0.43     10000
#    macro avg       0.54      0.55      0.43     10000
# weighted avg       0.67      0.43      0.44     10000
#
# {'accuracy': 0.4344, 'precision': 0.2825, 'recall': 0.7825, 'f1_score': 0.4151, 'roc_auc': 0.5776}
#
# // Segment # 2 //
# Confusion Matrix:
# [[3575 3860]
#  [ 952 1613]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.48      0.60      7435
#            1       0.29      0.63      0.40      2565
#
#     accuracy                           0.52     10000
#    macro avg       0.54      0.55      0.50     10000
# weighted avg       0.66      0.52      0.55     10000
#
# {'accuracy': 0.5188, 'precision': 0.2947, 'recall': 0.6288, 'f1_score': 0.4013, 'roc_auc': 0.5778}
#
# --------------------------------------------------
# ----- 3-cluster K-means -----
#
# // Segment # 1 //
# Confusion Matrix:
# [[2328 5107]
#  [ 557 2008]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.31      0.45      7435
#            1       0.28      0.78      0.41      2565
#
#     accuracy                           0.43     10000
#    macro avg       0.54      0.55      0.43     10000
# weighted avg       0.67      0.43      0.44     10000
#
# {'accuracy': 0.4336, 'precision': 0.2822, 'recall': 0.7828, 'f1_score': 0.4149, 'roc_auc': 0.5773}
#
# // Segment # 2 //
# Confusion Matrix:
# [[3659 3776]
#  [ 964 1601]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.49      0.61      7435
#            1       0.30      0.62      0.40      2565
#
#     accuracy                           0.53     10000
#    macro avg       0.54      0.56      0.51     10000
# weighted avg       0.66      0.53      0.55     10000
#
# {'accuracy': 0.526, 'precision': 0.2977, 'recall': 0.6242, 'f1_score': 0.4032, 'roc_auc': 0.5796}
#
# // Segment # 3 //
# Confusion Matrix:
# [[7434    1]
#  [2565    0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85      7435
#            1       0.00      0.00      0.00      2565
#
#     accuracy                           0.74     10000
#    macro avg       0.37      0.50      0.43     10000
# weighted avg       0.55      0.74      0.63     10000
#
# {'accuracy': 0.7434, 'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0, 'roc_auc': 0.5452}
#
# --------------------------------------------------
# ----- 4-cluster K-means -----
#
# // Segment # 1 //
# Confusion Matrix:
# [[1928 5507]
#  [ 499 2066]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.26      0.39      7435
#            1       0.27      0.81      0.41      2565
#
#     accuracy                           0.40     10000
#    macro avg       0.53      0.53      0.40     10000
# weighted avg       0.66      0.40      0.40     10000
#
# {'accuracy': 0.3994, 'precision': 0.2728, 'recall': 0.8055, 'f1_score': 0.4076, 'roc_auc': 0.5514}
#
# // Segment # 2 //
# Confusion Matrix:
# [[4495 2940]
#  [1288 1277]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.60      0.68      7435
#            1       0.30      0.50      0.38      2565
#
#     accuracy                           0.58     10000
#    macro avg       0.54      0.55      0.53     10000
# weighted avg       0.66      0.58      0.60     10000
#
# {'accuracy': 0.5772, 'precision': 0.3028, 'recall': 0.4979, 'f1_score': 0.3766, 'roc_auc': 0.5692}
#
# // Segment # 3 //
# Confusion Matrix:
# [[1667 5768]
#  [ 423 2142]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.22      0.35      7435
#            1       0.27      0.84      0.41      2565
#
#     accuracy                           0.38     10000
#    macro avg       0.53      0.53      0.38     10000
# weighted avg       0.66      0.38      0.37     10000
#
# {'accuracy': 0.3809, 'precision': 0.2708, 'recall': 0.8351, 'f1_score': 0.409, 'roc_auc': 0.5656}
#
# // Segment # 4 //
# Confusion Matrix:
# [[4910 2525]
#  [1469 1096]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.66      0.71      7435
#            1       0.30      0.43      0.35      2565
#
#     accuracy                           0.60     10000
#    macro avg       0.54      0.54      0.53     10000
# weighted avg       0.65      0.60      0.62     10000
#
# {'accuracy': 0.6006, 'precision': 0.3027, 'recall': 0.4273, 'f1_score': 0.3543, 'roc_auc': 0.5688}
#
# --------------------------------------------------
# ----- 5-cluster K-means -----
#
# // Segment # 1 //
# Confusion Matrix:
# [[2701 4734]
#  [ 624 1941]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.36      0.50      7435
#            1       0.29      0.76      0.42      2565
#
#     accuracy                           0.46     10000
#    macro avg       0.55      0.56      0.46     10000
# weighted avg       0.68      0.46      0.48     10000
#
# {'accuracy': 0.4642, 'precision': 0.2908, 'recall': 0.7567, 'f1_score': 0.4201, 'roc_auc': 0.5831}
#
# // Segment # 2 //
# Confusion Matrix:
# [[4603 2832]
#  [1341 1224]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.62      0.69      7435
#            1       0.30      0.48      0.37      2565
#
#     accuracy                           0.58     10000
#    macro avg       0.54      0.55      0.53     10000
# weighted avg       0.65      0.58      0.61     10000
#
# {'accuracy': 0.5827, 'precision': 0.3018, 'recall': 0.4772, 'f1_score': 0.3697, 'roc_auc': 0.5683}
#
# // Segment # 3 //
# Confusion Matrix:
# [[4820 2615]
#  [1423 1142]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.65      0.70      7435
#            1       0.30      0.45      0.36      2565
#
#     accuracy                           0.60     10000
#    macro avg       0.54      0.55      0.53     10000
# weighted avg       0.65      0.60      0.62     10000
#
# {'accuracy': 0.5962, 'precision': 0.304, 'recall': 0.4452, 'f1_score': 0.3613, 'roc_auc': 0.5654}
#
# // Segment # 4 //
# Confusion Matrix:
# [[2175 5260]
#  [ 588 1977]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.29      0.43      7435
#            1       0.27      0.77      0.40      2565
#
#     accuracy                           0.42     10000
#    macro avg       0.53      0.53      0.41     10000
# weighted avg       0.66      0.42      0.42     10000
#
# {'accuracy': 0.4152, 'precision': 0.2732, 'recall': 0.7708, 'f1_score': 0.4034, 'roc_auc': 0.5499}
#
# // Segment # 5 //
# Confusion Matrix:
# [[7434    1]
#  [2565    0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85      7435
#            1       0.00      0.00      0.00      2565
#
#     accuracy                           0.74     10000
#    macro avg       0.37      0.50      0.43     10000
# weighted avg       0.55      0.74      0.63     10000
#
# {'accuracy': 0.7434, 'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0, 'roc_auc': 0.5452}
#
# --------------------------------------------------
# ----- 6-cluster K-means -----
#
# // Segment # 1 //
# Confusion Matrix:
# [[1614 5821]
#  [ 404 2161]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.22      0.34      7435
#            1       0.27      0.84      0.41      2565
#
#     accuracy                           0.38     10000
#    macro avg       0.54      0.53      0.38     10000
# weighted avg       0.66      0.38      0.36     10000
#
# {'accuracy': 0.3775, 'precision': 0.2707, 'recall': 0.8425, 'f1_score': 0.4098, 'roc_auc': 0.5501}
#
# // Segment # 2 //
# Confusion Matrix:
# [[4086 3349]
#  [1131 1434]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.55      0.65      7435
#            1       0.30      0.56      0.39      2565
#
#     accuracy                           0.55     10000
#    macro avg       0.54      0.55      0.52     10000
# weighted avg       0.66      0.55      0.58     10000
#
# {'accuracy': 0.552, 'precision': 0.2998, 'recall': 0.5591, 'f1_score': 0.3903, 'roc_auc': 0.5708}
#
# // Segment # 3 //
# Confusion Matrix:
# [[1794 5641]
#  [ 444 2121]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.24      0.37      7435
#            1       0.27      0.83      0.41      2565
#
#     accuracy                           0.39     10000
#    macro avg       0.54      0.53      0.39     10000
# weighted avg       0.67      0.39      0.38     10000
#
# {'accuracy': 0.3915, 'precision': 0.2733, 'recall': 0.8269, 'f1_score': 0.4108, 'roc_auc': 0.5684}
#
# // Segment # 4 //
# Confusion Matrix:
# [[4703 2732]
#  [1407 1158]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.63      0.69      7435
#            1       0.30      0.45      0.36      2565
#
#     accuracy                           0.59     10000
#    macro avg       0.53      0.54      0.53     10000
# weighted avg       0.65      0.59      0.61     10000
#
# {'accuracy': 0.5861, 'precision': 0.2977, 'recall': 0.4515, 'f1_score': 0.3588, 'roc_auc': 0.559}
#
# // Segment # 5 //
# Confusion Matrix:
# [[2536 4899]
#  [ 726 1839]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.34      0.47      7435
#            1       0.27      0.72      0.40      2565
#
#     accuracy                           0.44     10000
#    macro avg       0.53      0.53      0.43     10000
# weighted avg       0.65      0.44      0.45     10000
#
# {'accuracy': 0.4375, 'precision': 0.2729, 'recall': 0.717, 'f1_score': 0.3954, 'roc_auc': 0.5473}
#
# // Segment # 6 //
# Confusion Matrix:
# [[7434    1]
#  [2565    0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85      7435
#            1       0.00      0.00      0.00      2565
#
#     accuracy                           0.74     10000
#    macro avg       0.37      0.50      0.43     10000
# weighted avg       0.55      0.74      0.63     10000
#
# {'accuracy': 0.7434, 'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0, 'roc_auc': 0.5452}
#
# --------------------------------------------------
# ----- 2-cluster Decision Trees -----
#
# // Segment # 1 //
# Confusion Matrix:
# [[5608 1827]
#  [1679  886]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76      7435
#            1       0.33      0.35      0.34      2565
#
#     accuracy                           0.65     10000
#    macro avg       0.55      0.55      0.55     10000
# weighted avg       0.66      0.65      0.65     10000
#
# {'accuracy': 0.6494, 'precision': 0.3266, 'recall': 0.3454, 'f1_score': 0.3357, 'roc_auc': 0.5805}
#
# // Segment # 2 //
# Confusion Matrix:
# [[ 946 6489]
#  [ 328 2237]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.13      0.22      7435
#            1       0.26      0.87      0.40      2565
#
#     accuracy                           0.32     10000
#    macro avg       0.50      0.50      0.31     10000
# weighted avg       0.62      0.32      0.26     10000
#
# {'accuracy': 0.3183, 'precision': 0.2564, 'recall': 0.8721, 'f1_score': 0.3962, 'roc_auc': 0.4862}

# %%
print("Metrics Summary", "\n(Mean value for each metric)")
print(metrics_summary(all_metrics, segmentation_names))
# Out:
# Metrics Summary
# (Mean value for each metric)
#                           accuracy  precision    recall  f1_score   roc_auc
# 2-cluster K-means         0.476600   0.288600  0.705650  0.408200  0.577700
# 3-cluster K-means         0.567667   0.193300  0.469000  0.272700  0.567367
# 4-cluster K-means         0.489525   0.287275  0.641450  0.386875  0.563750
# 5-cluster K-means         0.560340   0.233960  0.489980  0.310900  0.562380
# 6-cluster K-means         0.514667   0.235733  0.566167  0.327517  0.556800
# 2-cluster Decision Trees  0.483850   0.291500  0.608750  0.365950  0.533350
# ------------------- MEAN  0.515441   0.255061  0.580166  0.345357  0.560224

# %% [markdown]
# # ----------------------
