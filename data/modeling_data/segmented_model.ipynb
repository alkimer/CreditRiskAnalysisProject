# %% [markdown]
# # ---  2-phase Model ---

# %% [markdown]
# ## Start

# %%
from segmented_model import *
import pandas as pd

# %%
X_train_unb = pd.read_csv('../processed/interim/X_train_X_train_unbalanced.csv') #'../processed/X_train_balanced.csv')
y_train_unb = pd.read_csv('../processed/y_train_p.csv') #'../processed/y_train_balanced.csv')

# %%
X_train, y_train = randomOverSample(X_train_unb, y_train_unb, random_state=42)

# %% [markdown]
# # Phase 1: Segmentation

# %% [markdown]
# ## Kmeans Segmentation

# %% [markdown]
# ### 3-cluster Kmeans

# %%
km_clusters = 3
df_kmeans_segmented3 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented3, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 3):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.504696
# 0    0.495304
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.518521
# 1    0.481479
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.523339
# 0    0.476661
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 4-cluster Kmeans

# %%
km_clusters = 4
df_kmeans_segmented4 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented4, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 4):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.523066
# 0    0.476934
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 1    0.505867
# 0    0.494133
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 0    0.515594
# 1    0.484406
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.540193
# 1    0.459807
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 5-cluster Kmeans

# %%
km_clusters = 5
df_kmeans_segmented5 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented5, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 5):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.512333
# 0    0.487667
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.513589
# 1    0.486411
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.521317
# 0    0.478683
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.5181
# 1    0.4819
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 0    0.542898
# 1    0.457102
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 6-cluster Kmeans

# %%
km_clusters = 6
df_kmeans_segmented6 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented6, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 6):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 0    0.519659
# 1    0.480341
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.514366
# 1    0.485634
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.523437
# 0    0.476563
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.544493
# 1    0.455507
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    0.513422
# 0    0.486578
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 1    0.517769
# 0    0.482231
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 7-cluster Kmeans

# %%
km_clusters = 7
df_kmeans_segmented7 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented7, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 7):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.533866
# 0    0.466134
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.515271
# 1    0.484729
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.523096
# 0    0.476904
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.514182
# 1    0.485818
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 0    0.516872
# 1    0.483128
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 0    0.545411
# 1    0.454589
# Name: proportion, dtype: float64
# --------------------
# Segment 6:
# target
# 1    0.518469
# 0    0.481531
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 8-cluster Kmeans

# %%
km_clusters = 8
df_kmeans_segmented8 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', df_kmeans_segmented8, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 8):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.518475
# 0    0.481525
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 1    0.509896
# 0    0.490104
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 0    0.523096
# 1    0.476904
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 1    0.533199
# 0    0.466801
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    0.522934
# 0    0.477066
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 0    0.51259
# 1    0.48741
# Name: proportion, dtype: float64
# --------------------
# Segment 6:
# target
# 0    0.523588
# 1    0.476412
# Name: proportion, dtype: float64
# --------------------
# Segment 7:
# target
# 0    0.545764
# 1    0.454236
# ...

# %% [markdown]
# ## Decision Trees Segmentation

# %% [markdown]
# ### Decision trees, max_leafs = 3

# %%
dt_leafs = 3
df_dt_segmented3 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented3, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['dt_segment'] = dt_segmenter.apply(df_dt_segmented) #.drop('kmeans_segment', axis=1, errors='ignore'))
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['target'] = y_train.iloc[:, 0]
# ...

# %% [markdown]
# ### Decision trees, max_leafs = 4

# %%
dt_leafs = 4
df_dt_segmented4 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented4, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['dt_segment'] = dt_segmenter.apply(df_dt_segmented) #.drop('kmeans_segment', axis=1, errors='ignore'))
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['target'] = y_train.iloc[:, 0]
# ...

# %% [markdown]
# ### Decision trees, max_leafs = 5

# %%
dt_leafs = 5
df_dt_segmented5 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented5, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['dt_segment'] = dt_segmenter.apply(df_dt_segmented) #.drop('kmeans_segment', axis=1, errors='ignore'))
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['target'] = y_train.iloc[:, 0]
# ...

# %% [markdown]
# ### Decision trees, max_leafs = 6

# %%
dt_leafs = 6
df_dt_segmented6 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented6, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['dt_segment'] = dt_segmenter.apply(df_dt_segmented) #.drop('kmeans_segment', axis=1, errors='ignore'))
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['target'] = y_train.iloc[:, 0]
# ...

# %% [markdown]
# ### Decision trees, max_leafs = 7

# %%
dt_leafs = 7
df_dt_segmented7 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented7, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['dt_segment'] = dt_segmenter.apply(df_dt_segmented) #.drop('kmeans_segment', axis=1, errors='ignore'))
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['target'] = y_train.iloc[:, 0]
# ...

# %% [markdown]
# ### Decision trees, max_leafs = 8

# %%
dt_leafs = 8
df_dt_segmented8 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', df_dt_segmented8, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['dt_segment'] = dt_segmenter.apply(df_dt_segmented) #.drop('kmeans_segment', axis=1, errors='ignore'))
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_dt_segmented['target'] = y_train.iloc[:, 0]
# ...

# %% [markdown]
# # ---------------

# %% [markdown]
# # Phase 2: Logistic Regression

# %%
segmentations = [df_kmeans_segmented3,
                 df_kmeans_segmented4,
                 df_kmeans_segmented5,
                 df_kmeans_segmented6,
                 df_kmeans_segmented7,
                 df_kmeans_segmented8,
                 df_dt_segmented3,
                 df_dt_segmented4,
                 df_dt_segmented5,
                 df_dt_segmented6,
                 df_dt_segmented7,
                 df_dt_segmented8]

segmentation_names = ['3-cluster Kmeans',
                    '4-cluster Kmeans',
                    '5-cluster Kmeans',
                    '6-cluster Kmeans',
                    '7-cluster Kmeans',
                    '8-cluster Kmeans',
                    '3-cluster Decision Trees',
                    '4-cluster Decision Trees',
                    '5-cluster Decision Trees',
                    '6-cluster Decision Trees',
                    '7-cluster Decision Trees',
                    '8-cluster Decision Trees']

# %%
for i in range(12):    
    print(segmentation_names[i], "\n")
    second_phase(segmentations[i])
# Out:
# Confusion Matrix:
# [[4014 3421]
#  [ 922 1643]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.54      0.65      7435
#            1       0.32      0.64      0.43      2565
#
#     accuracy                           0.57     10000
#    macro avg       0.57      0.59      0.54     10000
# weighted avg       0.69      0.57      0.59     10000
#
# {'accuracy': 0.5657}
# Confusion Matrix:
# [[4014 3421]
#  [ 922 1643]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.54      0.65      7435
#            1       0.32      0.64      0.43      2565
#
#     accuracy                           0.57     10000
#    macro avg       0.57      0.59      0.54     10000
# weighted avg       0.69      0.57      0.59     10000
#
# {'accuracy': 0.5657}
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# # ----------------------

# %%
X_val = pd.read_csv('../processed/X_val_p.csv')
y_val = pd.read_csv('../processed/y_val.csv')

# %%
lr_model = train_logistic_regression(df_dt_segmented4)

# %%
metrics = evaluate_model(lr_model, X_val, y_val)
print(metrics)
# Out:
# Confusion Matrix:
# [[4014 3421]
#  [ 922 1643]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.54      0.65      7435
#            1       0.32      0.64      0.43      2565
#
#     accuracy                           0.57     10000
#    macro avg       0.57      0.59      0.54     10000
# weighted avg       0.69      0.57      0.59     10000
#
# {'accuracy': 0.5657}
