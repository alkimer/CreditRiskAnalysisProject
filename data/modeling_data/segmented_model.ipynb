# %% [markdown]
# # ---  2-phase Model ---

# %% [markdown]
# ## Start

# %%
from segmented_model import *

# %%
X_train_unb = pd.read_csv('../processed/interim/X_train_X_train_unbalanced.csv') #'../processed/X_train_balanced.csv')
y_train_unb = pd.read_csv('../processed/y_train_p.csv') #'../processed/y_train_balanced.csv')

# %%
X_train, y_train = randomOverSample(X_train_unb, y_train_unb, random_state=42)

# %% [markdown]
# # Phase 1: Segmentation

# %% [markdown]
# ## Kmeans Segmentation

# %% [markdown]
# ### 3-cluster Kmeans

# %%
km_clusters = 3
df_kmeans_segmented3 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', X_train, df_kmeans_segmented3, km_clusters)
# Out:
# --- K-Means Segmentation ---
# /home/aac/Anyone/FinalProject/CreditRiskAnalysisProject/data/modeling_data/segmented_model.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train['kmeans_segment'] = kmeans.fit_predict(X_train)
# K-Means segments distribution (N = 3):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.504696
# 0    0.495304
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.518521
# 1    0.481479
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.523339
# 0    0.476661
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 4-cluster Kmeans

# %%
km_clusters = 4
df_kmeans_segmented4 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', X_train, df_kmeans_segmented4, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 4):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.522935
# 0    0.477065
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.515412
# 1    0.484588
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.505957
# 0    0.494043
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.54505
# 1    0.45495
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 5-cluster Kmeans

# %%
km_clusters = 5
df_kmeans_segmented5 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', X_train, df_kmeans_segmented5, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 5):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.513402
# 0    0.486598
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.513286
# 1    0.486714
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.522702
# 0    0.477298
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.545275
# 1    0.454725
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 0    0.530185
# 1    0.469815
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 6-cluster Kmeans

# %%
km_clusters = 6
df_kmeans_segmented6 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', X_train, df_kmeans_segmented6, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 6):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 0    0.513286
# 1    0.486714
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 1    0.525625
# 0    0.474375
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 0    0.530157
# 1    0.469843
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.545409
# 1    0.454591
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    0.513402
# 0    0.486598
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 1    0.517735
# 0    0.482265
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 7-cluster Kmeans

# %%
km_clusters = 7
df_kmeans_segmented7 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', X_train, df_kmeans_segmented7, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 7):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.533325
# 0    0.466675
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.513286
# 1    0.486714
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 1    0.52564
# 0    0.47436
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.53013
# 1    0.46987
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    0.517741
# 0    0.482259
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 0    0.510846
# 1    0.489154
# Name: proportion, dtype: float64
# --------------------
# Segment 6:
# target
# 0    0.545409
# 1    0.454591
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### 8-cluster Kmeans

# %%
km_clusters = 8
df_kmeans_segmented8 = kmeans_segmentation(km_clusters, X_train, y_train)
visualize('kmeans_segment', X_train, df_kmeans_segmented8, km_clusters)
# Out:
# --- K-Means Segmentation ---
#
# K-Means segments distribution (N = 8):
#
#
# Target variable distribution within K-Means segments:
# Segment 0:
# target
# 1    0.52564
# 0    0.47436
# Name: proportion, dtype: float64
# --------------------
# Segment 1:
# target
# 0    0.53013
# 1    0.46987
# Name: proportion, dtype: float64
# --------------------
# Segment 2:
# target
# 0    0.521266
# 1    0.478734
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 0    0.545409
# 1    0.454591
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    0.533325
# 0    0.466675
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 0    0.510846
# 1    0.489154
# Name: proportion, dtype: float64
# --------------------
# Segment 6:
# target
# 1    0.517741
# 0    0.482259
# Name: proportion, dtype: float64
# --------------------
# Segment 7:
# target
# 1    0.506346
# 0    0.493654
# ...

# %% [markdown]
# ## Decision Trees Segmentation

# %% [markdown]
# ## -----

# %%
X_train_raw = pd.read_csv('../data_splitted/X_train.csv') #'../processed/X_train_balanced.csv')
y_train_raw = pd.read_csv('../data_splitted/y_train.csv') #'../processed/y_train_balanced.csv')

# %% [markdown]
# ## -----

# %% [markdown]
# ### Decision trees, max_leafs = 3

# %%
dt_leafs = 3
df_dt_segmented3 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', X_train, df_dt_segmented3, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
#
# Decision Tree segments distribution (Max leaf nodes aimed: 3):
# dt_segment
# 3    27684
# 4    21665
# 1     9699
# Name: count, dtype: int64
#
# Target variable distribution within Decision Tree segments:
# Segment 1:
# target
# 0    0.677699
# 1    0.322301
# Name: proportion, dtype: float64
# --------------------
# Segment 3:
# target
# 1    0.503612
# 0    0.496388
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 1    0.574937
# 0    0.425063
# Name: proportion, dtype: float64
# --------------------
# (59048, 126)

# %% [markdown]
# ### Decision trees, max_leafs = 4

# %%
dt_leafs = 4
df_dt_segmented4 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', X_train, df_dt_segmented4, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
#
# Decision Tree segments distribution (Max leaf nodes aimed: 4):
# dt_segment
# 5    22422
# 6    21665
# 4     9699
# 3     5262
# Name: count, dtype: int64
#
# Target variable distribution within Decision Tree segments:
# Segment 3:
# target
# 0    0.563664
# 1    0.436336
# Name: proportion, dtype: float64
# --------------------
# Segment 4:
# target
# 0    0.677699
# 1    0.322301
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 1    0.519401
# 0    0.480599
# Name: proportion, dtype: float64
# --------------------
# Segment 6:
# target
# 1    0.574937
# 0    0.425063
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# ### Decision trees, max_leafs = 5

# %%
dt_leafs = 5
df_dt_segmented2 = decision_trees_segmentation(dt_leafs, X_train, y_train)
visualize('dt_segment', X_train, df_dt_segmented2, dt_leafs)
# Out:
# --- Decision Tree Segmentation ---
#
# Decision Tree segments distribution (Max leaf nodes aimed: 5):
# dt_segment
# 5    22422
# 6    21665
# 7     8270
# 3     5262
# 8     1429
# Name: count, dtype: int64
#
# Target variable distribution within Decision Tree segments:
# Segment 3:
# target
# 0    0.563664
# 1    0.436336
# Name: proportion, dtype: float64
# --------------------
# Segment 5:
# target
# 1    0.519401
# 0    0.480599
# Name: proportion, dtype: float64
# --------------------
# Segment 6:
# target
# 1    0.574937
# 0    0.425063
# Name: proportion, dtype: float64
# --------------------
# Segment 7:
# target
# 0    0.697461
# 1    0.302539
# Name: proportion, dtype: float64
# --------------------
# Segment 8:
# target
# 0    0.563331
# 1    0.436669
# Name: proportion, dtype: float64
# --------------------

# %% [markdown]
# # ---------------

# %% [markdown]
# ## Segmentation Chosen: 4-cluster kmeans

# %% [markdown]
# ### Frecuency

# %%
df_kmeans_segmented4.shape
# Out:
# (59048, 126)

# %%
frecuency_by_segment(df_kmeans_segmented4)
# Out:
# === Frequency Summary for Segment '0' ===
#
# -- Column: APPLICATION_SUBMISSION_TYPE --
# APPLICATION_SUBMISSION_TYPE
# 2.0    4624
# 0.0    2657
# 1.0     503
# Name: count, dtype: int64
#
# -- Column: SEX --
# SEX
# 1.0    4154
# 0.0    3630
# Name: count, dtype: int64
#
# -- Column: FLAG_RESIDENCIAL_PHONE --
# FLAG_RESIDENCIAL_PHONE
# 1.0    6881
# 0.0     903
# Name: count, dtype: int64
#
# -- Column: FLAG_EMAIL --
# FLAG_EMAIL
# 1.0    6589
# 0.0    1195
# Name: count, dtype: int64
#
# -- Column: FLAG_VISA --
# FLAG_VISA
# 0.0    6269
# 1.0    1515
# Name: count, dtype: int64
#
# -- Column: FLAG_MASTERCARD --
# FLAG_MASTERCARD
# 0.0    6623
# 1.0    1161
# Name: count, dtype: int64
#
# -- Column: FLAG_OTHER_CARDS --
# FLAG_OTHER_CARDS
# 0.0    7771
# 1.0      13
# Name: count, dtype: int64
#
# -- Column: FLAG_PROFESSIONAL_PHONE --
# FLAG_PROFESSIONAL_PHONE
# 0.0    5177
# 1.0    2607
# Name: count, dtype: int64
#
# -- Column: STATE_OF_BIRTH_AC --
# STATE_OF_BIRTH_AC
# ...

# %% [markdown]
# ### Correlation

# %%
correlation_by_segment(df_kmeans_segmented4)

# %% [markdown]
# # Phase 2: Logistic Regression
