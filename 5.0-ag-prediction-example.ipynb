# %%
import pandas as pd
from credit_risk_analysis.modeling import predict
# Out:
# 2025-06-26 23:56:24.507 | INFO     | credit_risk_analysis.config:<module>:11 - PROJ_ROOT path is: C:\Users\andre\iCloudDrive\Documents_Backup\Digital_Bullet_Journal\Education\Data Science\Anyone AI\5. Final_Project\credit_risk_analysis

# %%
predict.main(features_path="data/external/X_fake_new_sample.csv", 
             predictions_path="data/processed/X_fake_new_predictions.csv",
             use_fake_data=True)
# Out:
# 2025-06-26 23:57:03.303 | INFO     | credit_risk_analysis.modeling.predict:main:53 - Performing inference for model...
# ✅ Datos falsos generados y guardados en data/external/X_fake_new_sample.csv.
# Iniciando procesamiento de características...
# ✅ Nuevos datos procesados y guardados correctamente.
# Procesamiento completado.
# ✅ Predicciones de riesgo crediticio completadas.
# 2025-06-26 23:57:08.340 | SUCCESS  | credit_risk_analysis.modeling.predict:main:63 - Inference complete.

# %%
X_new_predictions = pd.read_csv("data/processed/X_fake_new_predictions.csv")
X_new_predictions.head()
# Out:
#    PERSONAL_MONTHLY_INCOME  OTHER_INCOMES  PERSONAL_ASSETS_VALUE  \
# 0                 0.182188      -0.036265              -0.064454
# 1                 0.016001      -0.036265              -0.064454
# 2                -0.061869      -0.036265              -0.064454
# 3                -0.071569      -0.036265              -0.064454
# 4                -0.037888      -0.036265              -0.064454
#
#    MARITAL_STATUS  QUANT_DEPENDANTS  MONTHS_IN_RESIDENCE  \
# 0       -0.111857          0.294090            -0.724554
# 1       -0.111857         -0.541334             0.548268
# 2       -0.868794         -0.541334             0.156631
# 3       -0.868794         -0.541334            -0.332916
# 4        2.158957         -0.541334            -0.920372
#
#    QUANT_BANKING_ACCOUNTS  QUANT_CARS       AGE  PROFESSION_CODE  ...  \
# 0               -0.744233   -0.710039 -0.217743        -0.407199  ...
# 1                1.340453    1.408374 -1.285201         0.265246  ...
# ...

# %%
X_new_predictions["PROBABILITY_BAD=1"].describe()
# Out:
# count    1000.000000
# mean        0.490716
# std         0.107760
# min         0.179264
# 25%         0.411948
# 50%         0.507647
# 75%         0.573142
# max         0.730767
# Name: PROBABILITY_BAD=1, dtype: float64
